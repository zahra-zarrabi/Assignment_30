# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image=np.zeros((128,285,3),dtype=np.uint8)
image[:,:]=[83,83,83]
image[42:62,44:64]=[255,0,0]
image[42:62,66:86]=[0,255,0]
image[64:84,44:64]=[0,0,255]
image[64:84,66:86]=[255,255,0]

plt.text(88,80,'Microsoft',color='white',fontsize=40)
plt.imshow(image)
